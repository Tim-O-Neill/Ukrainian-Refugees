# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/Refugee data query_data (1)/population.csv', on_bad_lines='skip')

# %%
df
# Out:
#                                            Extracted:  \
# 0                                     Date extracted:
# 1                                       Last updated:
# 2   Some data presented may differ from statistics...
# 3                  Data table contains the following:
# 4                                        Content type
# 5                                     Data quick link
# 6                                    Data definitions
# 7                                       Usage licence
# 8                           Population types included
# 9                                              Years:
# 10                                            Origin:
# 11                                 Country of asylum:
#
#         United Nations High Commissioner for Refugees
# 0                                08/03/2022 13:39 UTC
# 1                                    10 November 2021
# 2                                                 NaN
# ...
