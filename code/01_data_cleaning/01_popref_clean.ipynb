# %% [markdown]
# # Read in Refugee Data
# ---
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Extracted:,"United Nations High Commissioner for Refugees"
# "Date extracted:","08/03/2022 13:39 UTC"
# "Last updated:","10 November 2021"
# "Some data presented may differ from statistics published previously due to retroactive changes or the inclusion of previously unavailable data."
#
# "Data table contains the following:","Population figures"
# "Content type","End year stock population totals"
# "Data quick link",https://www.unhcr.org/refugee-statistics/download/?url=VHI7gj
# "Data definitions",https://www.unhcr.org/refugee-statistics/methodology/
# "Usage licence",https://creativecommons.org/licenses/by/4.0/
# "Population types included","REF,ROC,ASY,IDP,IOC,VDA,OOC,STA"
# Years:
# Origin:,all
# "Country of asylum:",all

# %%
df = pd.read_csv('../../data/Refugee data query_data (1)/population.csv')

# %%
df
# Out:
#        Year Country of origin Country of origin (ISO)  \
# 0      2016       Afghanistan                     AFG
# 1      2016       Afghanistan                     AFG
# 2      2016       Afghanistan                     AFG
# 3      2016       Afghanistan                     AFG
# 4      2016       Afghanistan                     AFG
# ...     ...               ...                     ...
# 31741  2021          Zimbabwe                     ZWE
# 31742  2021          Zimbabwe                     ZWE
# 31743  2021          Zimbabwe                     ZWE
# 31744  2021          Zimbabwe                     ZWE
# 31745  2021          Zimbabwe                     ZWE
#
#               Country of asylum Country of asylum (ISO)  \
# 0                   Afghanistan                     AFG
# 1                         Egypt                     EGY
# 2                     Argentina                     ARG
# 3                     Australia                     AUS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31746 entries, 0 to 31745
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            31746 non-null  int64
#  1   Country of origin               31746 non-null  object
#  2   Country of origin (ISO)         31447 non-null  object
#  3   Country of asylum               31746 non-null  object
#  4   Country of asylum (ISO)         31746 non-null  object
#  5   Refugees under UNHCR's mandate  31746 non-null  int64
#  6   Asylum-seekers                  31746 non-null  int64
#  7   IDPs of concern to UNHCR        31746 non-null  int64
#  8   Venezuelans displaced abroad    83 non-null     float64
#  9   Stateless persons               31746 non-null  int64
#  10  Others of concern               31746 non-null  int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 2.7+ MB

# %%
df.isnull().sum()
# Out:
# Year                                  0
# Country of origin                     0
# Country of origin (ISO)             299
# Country of asylum                     0
# Country of asylum (ISO)               0
# Refugees under UNHCR's mandate        0
# Asylum-seekers                        0
# IDPs of concern to UNHCR              0
# Venezuelans displaced abroad      31663
# Stateless persons                     0
# Others of concern                     0
# dtype: int64

# %%
df.drop(columns ='Venezuelans displaced abroad', inplace = True)

# %%
df.isnull().sum()
# Out:
# Year                                0
# Country of origin                   0
# Country of origin (ISO)           299
# Country of asylum                   0
# Country of asylum (ISO)             0
# Refugees under UNHCR's mandate      0
# Asylum-seekers                      0
# IDPs of concern to UNHCR            0
# Stateless persons                   0
# Others of concern                   0
# dtype: int64

# %%
df[df['Country of origin (ISO)'].isnull()]
# Out:
#        Year Country of origin Country of origin (ISO)  \
# 4579   2016          Unknown                      NaN
# 4580   2016          Unknown                      NaN
# 4581   2016          Unknown                      NaN
# 4582   2016          Unknown                      NaN
# 4583   2016          Unknown                      NaN
# ...     ...               ...                     ...
# 31362  2021          Unknown                      NaN
# 31363  2021          Unknown                      NaN
# 31364  2021          Unknown                      NaN
# 31365  2021          Unknown                      NaN
# 31366  2021          Unknown                      NaN
#
#               Country of asylum Country of asylum (ISO)  \
# 4579                      Egypt                     EGY
# 4580                  Argentina                     ARG
# 4581                  Australia                     AUS
# 4582                    Austria                     AUT
# ...

# %%
df.sort_values(by = 'Country of asylum')
# Out:
#        Year       Country of origin Country of origin (ISO) Country of asylum  \
# 0      2016             Afghanistan                     AFG       Afghanistan
# 2029   2016  Iran (Islamic Rep. of)                     IRN       Afghanistan
# 20172  2019                  Turkey                     TUR       Afghanistan
# 26746  2021              Bangladesh                     BGD       Afghanistan
# 14611  2018              Tajikistan                     TJK       Afghanistan
# ...     ...                     ...                     ...               ...
# 16866  2019                 Eritrea                     ERI          Zimbabwe
# 28889  2021                   Kenya                     KEN          Zimbabwe
# 4111   2016                   Sudan                     SDN          Zimbabwe
# 8009   2017              Mozambique                     MOZ          Zimbabwe
# 31745  2021                Zimbabwe                     ZWE          Zimbabwe
#
# ...

# %%
df.drop(columns = ['Country of origin', 'Country of origin (ISO)'], inplace=True)

# %%
rf = df.groupby(['Year', 'Country of asylum', 'Country of asylum (ISO)'])["Refugees under UNHCR's mandate", 'Asylum-seekers',
       'IDPs of concern to UNHCR', 'Stateless persons', 'Others of concern'].sum().reset_index()
# Out:
# /var/folders/8c/d71xvtx971706d0ttvg_stb80000gn/T/ipykernel_59522/3054844471.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rf = df.groupby(['Year', 'Country of asylum', 'Country of asylum (ISO)'])["Refugees under UNHCR's mandate", 'Asylum-seekers',

# %%
rf = rf.sort_values(by = ['Country of asylum', 'Year'])

# %%
rf.head(10)
# Out:
#      Year Country of asylum Country of asylum (ISO)  \
# 0    2016       Afghanistan                     AFG
# 175  2017       Afghanistan                     AFG
# 349  2018       Afghanistan                     AFG
# 525  2019       Afghanistan                     AFG
# 701  2020       Afghanistan                     AFG
# 878  2021       Afghanistan                     AFG
# 1    2016           Albania                     ALB
# 176  2017           Albania                     ALB
# 350  2018           Albania                     ALB
# 526  2019           Albania                     ALB
#
#      Refugees under UNHCR's mandate  Asylum-seekers  IDPs of concern to UNHCR  \
# 0                             59770             123                   1797551
# 175                           75927             215                   1837079
# 349                           72228             281                   2106893
# ...

# %%
rf.to_csv('../../data/pop_refugees_clean.csv')
