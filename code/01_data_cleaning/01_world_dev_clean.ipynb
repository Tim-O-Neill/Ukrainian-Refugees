# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/world_dev_indicators.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/8c/d71xvtx971706d0ttvg_stb80000gn/T/ipykernel_79722/2718851973.py in <module>
# ----> 1 df = pd.read_csv('../../data/world_dev_indicators.csv')
#       2 df.head()
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /Applications/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/world_dev_indicators.csv'

# %%
df['findex']=df.index
df
# Out:
#                                            Country Name Country Code  \
# 0                                           Afghanistan          AFG
# 1                                           Afghanistan          AFG
# 2                                           Afghanistan          AFG
# 3                                           Afghanistan          AFG
# 4                                           Afghanistan          AFG
# ...                                                 ...          ...
# 18354                                               NaN          NaN
# 18355                                               NaN          NaN
# 18356                                               NaN          NaN
# 18357  Data from database: World Development Indicators          NaN
# 18358                          Last Updated: 02/15/2022          NaN
#
#                                              Series Name         2016  \
# 0      Adequacy of social safety net programs (% of t...           ..
# 1      Adjusted savings: net national savings (curren...           ..
# 2      Adolescent fertility rate (births per 1,000 wo...       75.325
# 3      Adjusted savings: particulate emission damage ...  577403184.3
# 4                      Air transport, passengers carried      1917924
# ...                                                  ...          ...
# 18354                                                NaN          NaN
# 18355                                                NaN          NaN
# 18356                                                NaN          NaN
# 18357                                                NaN          NaN
# 18358                                                NaN          NaN
#
#               2017         2018         2019        2020  findex
# 0               ..           ..           ..          ..       0
# 1               ..           ..           ..          ..       1
# 2           68.957       65.141       61.325          ..       2
# 3      575149709.4  557892202.2  521580871.8          ..       3
# 4          1647425      1125367  1066747.356  449041.025       4
# ...            ...          ...          ...         ...     ...
# 18354          NaN          NaN          NaN         NaN   18354
# 18355          NaN          NaN          NaN         NaN   18355
# 18356          NaN          NaN          NaN         NaN   18356
# 18357          NaN          NaN          NaN         NaN   18357
# 18358          NaN          NaN          NaN         NaN   18358
#
# [18359 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18359 entries, 0 to 18358
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  18356 non-null  object
#  1   Country Code  18354 non-null  object
#  2   Series Name   18354 non-null  object
#  3   2016          18354 non-null  object
#  4   2017          18354 non-null  object
#  5   2018          18354 non-null  object
#  6   2019          18354 non-null  object
#  7   2020          18354 non-null  object
#  8   findex        18359 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 1.3+ MB

# %%
col_list = df['Series Name'].unique()

# %%
col_list
# Out:
# array(['Adequacy of social safety net programs (% of total welfare of beneficiary households)',
#        'Adjusted savings: net national savings (current US$)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Adjusted savings: particulate emission damage (current US$)',
#        'Air transport, passengers carried',
#        'Alternative and nuclear energy (% of total energy use)',
#        'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
#        'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
#        'Central government debt, total (% of GDP)',
#        'Children in employment, total (% of children ages 7-14)',
#        'Children in employment, unpaid family workers (% of children in employment, ages 7-14)',
#        'Coverage of social insurance programs (% of population)',
#        'Coverage of social protection and labor programs (% of population)',
#        'Coverage of social safety net programs (% of population)',
#        'Coverage of unemployment benefits and ALMP (% of population)',
#        'CPIA financial sector rating (1=low to 6=high)',
#        'Current education expenditure, primary (% of total expenditure in primary public institutions)',
#        'Current health expenditure (% of GDP)',
#        'Current health expenditure per capita (current US$)',
#        'Death rate, crude (per 1,000 people)',
#        'Domestic private health expenditure per capita (current US$)',
#        'Domestic general government health expenditure per capita (current US$)',
#        'Ease of doing business score (0 = lowest performance to 100 = best performance)',
#        'Electric power consumption (kWh per capita)',
#        'Expenditure on primary education (% of government expenditure on education)',
#        'Expenditure on secondary education (% of government expenditure on education)',
#        'Fixed broadband subscriptions (per 100 people)',
#        'Fixed telephone subscriptions (per 100 people)',
#        'Gini index (World Bank estimate)', 'GNI growth (annual %)',
#        'Intentional homicides (per 100,000 people)',
#        'Internally displaced persons, new displacement associated with conflict and violence (number of cases)',
#        'Internally displaced persons, new displacement associated with disasters (number of cases)',
#        'International tourism, expenditures (current US$)',
#        'International tourism, receipts (current US$)',
#        'Military expenditure (current USD)',
#        'Multidimensional poverty index (scale 0-1)',
#        'Net official flows from UN agencies, UNECE (current US$)',
#        'Net official flows from UN agencies, UNDP (current US$)',
#        'Net official flows from UN agencies, UNAIDS (current US$)',
#        'Net official flows from UN agencies, UNEP (current US$)',
#        'Net official flows from UN agencies, UNFPA (current US$)',
#        'Net official flows from UN agencies, UNHCR (current US$)',
#        'Net official flows from UN agencies, UNICEF (current US$)',
#        'Net official flows from UN agencies, IAEA (current US$)',
#        'Net official flows from UN agencies, IFAD (current US$)',
#        'Net official flows from UN agencies, ILO (current US$)',
#        'Net official flows from UN agencies, FAO (current US$)',
#        'Net official flows from UN agencies, UNIDIR (current US$)',
#        'Net official flows from UN agencies, UNPBF (current US$)',
#        'Net official flows from UN agencies, UNRWA (current US$)',
#        'Net official flows from UN agencies, UNTA (current US$)',
#        'Net official flows from UN agencies, UNWTO (current US$)',
#        'Net official flows from UN agencies, WFP (current US$)',
#        'Net official flows from UN agencies, WHO (current US$)',
#        'Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure',
#        'Nurses and midwives (per 1,000 people)',
#        'People with basic handwashing facilities including soap and water (% of population)',
#        'Population density (people per sq. km of land area)',
#        'Population growth (annual %)',
#        'Population living in slums (% of urban population)',
#        'Prevalence of undernourishment (% of population)',
#        'Refugee population by country or territory of asylum',
#        'Share of youth not in education, employment or training, total (% of youth population)',
#        'Strength of legal rights index (0=weak to 12=strong)',
#        'Tax revenue (current LCU)', 'Tax revenue (% of GDP)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        nan], dtype=object)

# %%
df.set_index(["findex","Country Name","Country Code"], inplace=True)
new_df = df.stack().unstack(level=0)
new_df.head(10)
# Out:
# findex                                                                             0      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Adequacy of social safety net programs (% of t...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                             1      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Adjusted savings: net national savings (curren...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                             2      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Adolescent fertility rate (births per 1,000 wo...
#                           2016                                                    75.325
#                           2017                                                    68.957
#                           2018                                                    65.141
#                           2019                                                    61.325
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                             3      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Adjusted savings: particulate emission damage ...
#                           2016                                               577403184.3
#                           2017                                               575149709.4
#                           2018                                               557892202.2
#                           2019                                               521580871.8
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                             4      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Air transport, passengers carried
#                           2016                                   1917924
#                           2017                                   1647425
#                           2018                                   1125367
#                           2019                               1066747.356
#                           2020                                449041.025
# Albania      ALB          Series Name                                NaN
#                           2016                                       NaN
#                           2017                                       NaN
#                           2018                                       NaN
#
# findex                                                                             5      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Alternative and nuclear energy (% of total ene...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                             6      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Annualized average growth rate in per capita r...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                             7      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Annualized average growth rate in per capita r...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                                                     8      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Central government debt, total (% of GDP)
#                           2016                                                ..
#                           2017                                                ..
#                           2018                                                ..
#                           2019                                                ..
#                           2020                                                ..
# Albania      ALB          Series Name                                        NaN
#                           2016                                               NaN
#                           2017                                               NaN
#                           2018                                               NaN
#
# findex                                                                             9      \
# Country Name Country Code
# Afghanistan  AFG          Series Name  Children in employment, total (% of children a...
#                           2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
# Albania      ALB          Series Name                                                NaN
#                           2016                                                       NaN
#                           2017                                                       NaN
#                           2018                                                       NaN
#
# findex                                 ... 18344 18345 18346 18347 18348  \
# Country Name Country Code              ...
# Afghanistan  AFG          Series Name  ...   NaN   NaN   NaN   NaN   NaN
#                           2016         ...   NaN   NaN   NaN   NaN   NaN
#                           2017         ...   NaN   NaN   NaN   NaN   NaN
#                           2018         ...   NaN   NaN   NaN   NaN   NaN
#                           2019         ...   NaN   NaN   NaN   NaN   NaN
#                           2020         ...   NaN   NaN   NaN   NaN   NaN
# Albania      ALB          Series Name  ...   NaN   NaN   NaN   NaN   NaN
#                           2016         ...   NaN   NaN   NaN   NaN   NaN
#                           2017         ...   NaN   NaN   NaN   NaN   NaN
#                           2018         ...   NaN   NaN   NaN   NaN   NaN
#
# findex                                18349 18350 18351 18352 18353
# Country Name Country Code
# Afghanistan  AFG          Series Name   NaN   NaN   NaN   NaN   NaN
#                           2016          NaN   NaN   NaN   NaN   NaN
#                           2017          NaN   NaN   NaN   NaN   NaN
#                           2018          NaN   NaN   NaN   NaN   NaN
#                           2019          NaN   NaN   NaN   NaN   NaN
#                           2020          NaN   NaN   NaN   NaN   NaN
# Albania      ALB          Series Name   NaN   NaN   NaN   NaN   NaN
#                           2016          NaN   NaN   NaN   NaN   NaN
#                           2017          NaN   NaN   NaN   NaN   NaN
#                           2018          NaN   NaN   NaN   NaN   NaN
#
# [10 rows x 18354 columns]

# %%
new_header = new_df.iloc[0] #grab the first row for the header
new_df = new_df[1:] #take the data less the header row
new_df.columns = new_header #set the header row as the df header

# %%
new_df.head()
# Out:
# ('Afghanistan', 'AFG', 'Series Name') Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: net national savings (current US$)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                    75.325
#                           2017                                                    68.957
#                           2018                                                    65.141
#                           2019                                                    61.325
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: particulate emission damage (current US$)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                               577403184.3
#                           2017                                               575149709.4
#                           2018                                               557892202.2
#                           2019                                               521580871.8
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Air transport, passengers carried  \
# Country Name Country Code
# Afghanistan  AFG          2016                                  1917924
#                           2017                                  1647425
#                           2018                                  1125367
#                           2019                              1066747.356
#                           2020                               449041.025
#
# ('Afghanistan', 'AFG', 'Series Name') Alternative and nuclear energy (% of total energy use)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Annualized average growth rate in per capita real survey mean consumption or income, total population (%)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name') Central government debt, total (% of GDP)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                               ..
#                           2017                                               ..
#                           2018                                               ..
#                           2019                                               ..
#                           2020                                               ..
#
# ('Afghanistan', 'AFG', 'Series Name') Children in employment, total (% of children ages 7-14)  \
# Country Name Country Code
# Afghanistan  AFG          2016                                                        ..
#                           2017                                                        ..
#                           2018                                                        ..
#                           2019                                                        ..
#                           2020                                                        ..
#
# ('Afghanistan', 'AFG', 'Series Name')  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# Country Name Country Code              ...
# Afghanistan  AFG          2016         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                           2017         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                           2018         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                           2019         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                           2020         ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ('Afghanistan', 'AFG', 'Series Name')  NaN  NaN  NaN
# Country Name Country Code
# Afghanistan  AFG          2016         NaN  NaN  NaN
#                           2017         NaN  NaN  NaN
#                           2018         NaN  NaN  NaN
#                           2019         NaN  NaN  NaN
#                           2020         NaN  NaN  NaN
#
# [5 rows x 18354 columns]

# %%
new_df.reset_index(inplace=True)

# %%
new_df.head()
# Out:
# ('Afghanistan', 'AFG', 'Series Name') Country Name Country Code level_2  \
# 0                                      Afghanistan          AFG    2016
# 1                                      Afghanistan          AFG    2017
# 2                                      Afghanistan          AFG    2018
# 3                                      Afghanistan          AFG    2019
# 4                                      Afghanistan          AFG    2020
#
# ('Afghanistan', 'AFG', 'Series Name') Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: net national savings (current US$)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                                                 75.325
# 1                                                                                 68.957
# 2                                                                                 65.141
# 3                                                                                 61.325
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: particulate emission damage (current US$)  \
# 0                                                                            577403184.3
# 1                                                                            575149709.4
# 2                                                                            557892202.2
# 3                                                                            521580871.8
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Air transport, passengers carried  \
# 0                                                               1917924
# 1                                                               1647425
# 2                                                               1125367
# 3                                                           1066747.356
# 4                                                            449041.025
#
# ('Afghanistan', 'AFG', 'Series Name') Alternative and nuclear energy (% of total energy use)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name')  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  \
# 0                                      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                                      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                                      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                                      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                                      ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# ('Afghanistan', 'AFG', 'Series Name')  NaN  NaN  NaN
# 0                                      NaN  NaN  NaN
# 1                                      NaN  NaN  NaN
# 2                                      NaN  NaN  NaN
# 3                                      NaN  NaN  NaN
# 4                                      NaN  NaN  NaN
#
# [5 rows x 18357 columns]

# %%
new_df.rename(columns={'level_2': 'Year'}, inplace=True)

# %%
new_df2= new_df[['Country Name',
                 'Country Code','Year',
                 'Adequacy of social safety net programs (% of total welfare of beneficiary households)',
       'Adjusted savings: net national savings (current US$)',
       'Adolescent fertility rate (births per 1,000 women ages 15-19)',
       'Adjusted savings: particulate emission damage (current US$)',
       'Air transport, passengers carried',
       'Alternative and nuclear energy (% of total energy use)',
       'Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)',
       'Annualized average growth rate in per capita real survey mean consumption or income, total population (%)',
       'Central government debt, total (% of GDP)',
       'Children in employment, total (% of children ages 7-14)',
       'Children in employment, unpaid family workers (% of children in employment, ages 7-14)',
       'Coverage of social insurance programs (% of population)',
       'Coverage of social protection and labor programs (% of population)',
       'Coverage of social safety net programs (% of population)',
       'Coverage of unemployment benefits and ALMP (% of population)',
       'CPIA financial sector rating (1=low to 6=high)',
       'Current education expenditure, primary (% of total expenditure in primary public institutions)',
       'Current health expenditure (% of GDP)',
       'Current health expenditure per capita (current US$)',
       'Death rate, crude (per 1,000 people)',
       'Domestic private health expenditure per capita (current US$)',
       'Domestic general government health expenditure per capita (current US$)',
       'Ease of doing business score (0 = lowest performance to 100 = best performance)',
       'Electric power consumption (kWh per capita)',
       'Expenditure on primary education (% of government expenditure on education)',
       'Expenditure on secondary education (% of government expenditure on education)',
       'Fixed broadband subscriptions (per 100 people)',
       'Fixed telephone subscriptions (per 100 people)',
       'Gini index (World Bank estimate)', 'GNI growth (annual %)',
       'Intentional homicides (per 100,000 people)',
       'Internally displaced persons, new displacement associated with conflict and violence (number of cases)',
       'Internally displaced persons, new displacement associated with disasters (number of cases)',
       'International tourism, expenditures (current US$)',
       'International tourism, receipts (current US$)',
       'Military expenditure (current USD)',
       'Multidimensional poverty index (scale 0-1)',
       'Net official flows from UN agencies, UNECE (current US$)',
       'Net official flows from UN agencies, UNDP (current US$)',
       'Net official flows from UN agencies, UNAIDS (current US$)',
       'Net official flows from UN agencies, UNEP (current US$)',
       'Net official flows from UN agencies, UNFPA (current US$)',
       'Net official flows from UN agencies, UNHCR (current US$)',
       'Net official flows from UN agencies, UNICEF (current US$)',
       'Net official flows from UN agencies, IAEA (current US$)',
       'Net official flows from UN agencies, IFAD (current US$)',
       'Net official flows from UN agencies, ILO (current US$)',
       'Net official flows from UN agencies, FAO (current US$)',
       'Net official flows from UN agencies, UNIDIR (current US$)',
       'Net official flows from UN agencies, UNPBF (current US$)',
       'Net official flows from UN agencies, UNRWA (current US$)',
       'Net official flows from UN agencies, UNTA (current US$)',
       'Net official flows from UN agencies, UNWTO (current US$)',
       'Net official flows from UN agencies, WFP (current US$)',
       'Net official flows from UN agencies, WHO (current US$)',
       'Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure',
       'Nurses and midwives (per 1,000 people)',
       'People with basic handwashing facilities including soap and water (% of population)',
       'Population density (people per sq. km of land area)',
       'Population growth (annual %)',
       'Population living in slums (% of urban population)',
       'Prevalence of undernourishment (% of population)',
       'Refugee population by country or territory of asylum',
       'Share of youth not in education, employment or training, total (% of youth population)',
       'Strength of legal rights index (0=weak to 12=strong)',
       'Tax revenue (current LCU)', 'Tax revenue (% of GDP)',
       'Unemployment, total (% of total labor force) (national estimate)',
       'Unemployment, total (% of total labor force) (modeled ILO estimate)']]

# %%
new_df2.head()
# Out:
# ('Afghanistan', 'AFG', 'Series Name') Country Name Country Code  Year  \
# 0                                      Afghanistan          AFG  2016
# 1                                      Afghanistan          AFG  2017
# 2                                      Afghanistan          AFG  2018
# 3                                      Afghanistan          AFG  2019
# 4                                      Afghanistan          AFG  2020
#
# ('Afghanistan', 'AFG', 'Series Name') Adequacy of social safety net programs (% of total welfare of beneficiary households)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: net national savings (current US$)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                                                 75.325
# 1                                                                                 68.957
# 2                                                                                 65.141
# 3                                                                                 61.325
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Adjusted savings: particulate emission damage (current US$)  \
# 0                                                                            577403184.3
# 1                                                                            575149709.4
# 2                                                                            557892202.2
# 3                                                                            521580871.8
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Air transport, passengers carried  \
# 0                                                               1917924
# 1                                                               1647425
# 2                                                               1125367
# 3                                                           1066747.356
# 4                                                            449041.025
#
# ('Afghanistan', 'AFG', 'Series Name') Alternative and nuclear energy (% of total energy use)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Annualized average growth rate in per capita real survey mean consumption or income, bottom 40% of population (%)  \
# 0                                                                                     ..
# 1                                                                                     ..
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name')  ... Population growth (annual %)  \
# 0                                      ...                  2.778034788
# 1                                      ...                   2.54783304
# 2                                      ...                  2.384309079
# 3                                      ...                  2.313073349
# 4                                      ...                  2.303812093
#
# ('Afghanistan', 'AFG', 'Series Name') Population living in slums (% of urban population)  \
# 0                                                                            71.30000305
# 1                                                                                     ..
# 2                                                                            70.69999695
# 3                                                                                     ..
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Prevalence of undernourishment (% of population)  \
# 0                                                                                 22.2
# 1                                                                                   23
# 2                                                                                 23.4
# 3                                                                                 25.6
# 4                                                                                   ..
#
# ('Afghanistan', 'AFG', 'Series Name') Refugee population by country or territory of asylum  \
# 0                                                                                  59770
# 1                                                                                  75927
# 2                                                                                  72228
# 3                                                                                  72227
# 4                                                                                  72278
#
# ('Afghanistan', 'AFG', 'Series Name') Share of youth not in education, employment or training, total (% of youth population)  \
# 0                                                                                     ..
# 1                                                                            42.00999832
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                            53.75999832
#
# ('Afghanistan', 'AFG', 'Series Name') Strength of legal rights index (0=weak to 12=strong)  \
# 0                                                                                      9
# 1                                                                                      9
# 2                                                                                     10
# 3                                                                                     10
# 4                                                                                     ..
#
# ('Afghanistan', 'AFG', 'Series Name') Tax revenue (current LCU)  \
# 0                                                    1.1621E+11
# 1                                                   1.27241E+11
# 2                                                            ..
# 3                                                            ..
# 4                                                            ..
#
# ('Afghanistan', 'AFG', 'Series Name') Tax revenue (% of GDP)  \
# 0                                                9.502652783
# 1                                                9.898450897
# 2                                                         ..
# 3                                                         ..
# 4                                                         ..
#
# ('Afghanistan', 'AFG', 'Series Name') Unemployment, total (% of total labor force) (national estimate)  \
# 0                                                                                     ..
# 1                                                                            11.18000031
# 2                                                                                     ..
# 3                                                                                     ..
# 4                                                                            11.71000004
#
# ('Afghanistan', 'AFG', 'Series Name') Unemployment, total (% of total labor force) (modeled ILO estimate)
# 0                                                                            11.15799999
# 1                                                                            11.18000031
# 2                                                                            11.15200043
# 3                                                                            11.21700001
# 4                                                                            11.71000004
#
# [5 rows x 72 columns]

# %%
new_df2.pd.to_csv('../../data/clean_world_indic_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8c/d71xvtx971706d0ttvg_stb80000gn/T/ipykernel_79684/3868922210.py in <module>
# ----> 1 new_df2.pd.to_csv('../../data/clean_world_indic_data.csv')
#
# NameError: name 'new_df2' is not defined
